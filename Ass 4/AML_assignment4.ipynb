# %% [markdown]
# # Advanced Machine Learning - programming assignment 4
#
# *Due: Friday January 26*

# %% [markdown]
# **Please fill in:**
# * Alexo Castro Yáñez (2934213)
# * Ettore Cesari (1657399)

# %% [markdown]
# ### Further instructions:
# * Code quality is considered during the assessment. Use sensible variable names, and make sure your code is properly commented.
# * Submit your code in Blackboard using one of your accounts; we will put the grade in Blackboard for the other team member as well.
# * Make sure to name the submitted file according to your and your collaborators last name. (`submitter_collaborator.ipynb`)
# * **Failure to follow these instructions can affect the assignment grade.**

# %% [markdown]
# ## Implementing the PC algorithm
# In this assignment, you will complete an implementation of the PC algorithm. After that, you will use it to discover causal relations in a data set. Each of these two parts is worth 5 points.

# %% [markdown]
# The PC algorithm will need to keep track of a PDAG. We will represent this PDAG by a numpy array `G` of booleans.
#
# The matrix `G` represents a graph as follows:
# * For all `x`, `G[x,x] == False`
# * `G[x,y] == False` and `G[y,x] == False` means: no edge between x and y
# * `G[x,y] == True` and `G[y,x] == True` means: an undirected edge x&mdash;y
# * `G[x,y] == True` and `G[y,x] == False`means: a directed edge x$\to$y

# %%
import itertools

from AML_assignment4_util import *

# %% [markdown]
# The graphviz package can draw graphs to different file formats, or show them directly in the notebook. The function `graph_to_graphviz(G, node_names)` (from the file `AML_assignment4_util.py`) converts a numpy array of the form described above to a graph in graphviz format.

# %%
# Demonstration of graph_to_graphviz:
node_names = ['X', 'Y', 'Z', 'W']
G1 = np.zeros((4, 4), dtype=bool)
G1[0, 1] = G1[2, 1] = True  # two directed edges
G1[2, 3] = G1[3, 2] = True  # an undirected edge
d = graph_to_graphviz(G1, node_names)
d  # must be final line of code block to be displayed

# %% [markdown]
# Here is a Python class for performing the PC algorithm (when an object of this class is created and its `run` function is called). Add the missing code for phase 2, and implement phases 3 and 4. In the next section, you'll find some test cases to see if your code runs without errors and does what you expect it to.

# %%
class PC_algorithm:
    def __init__(self, independence_tester, verbose=1):
        # verbose can be 0 (silent), 1 (report independences), or 2 (also report dependences)
        self.independence_tester = independence_tester
        self.n = independence_tester.n_observed
        self.node_names = independence_tester.node_names
        self.verbose = verbose
        self.G = np.logical_not(np.eye(self.n, dtype=bool))
        self.sepset = dict()

    def skeleton_search(self):
        # PHASE II: Skeleton search
        # Note: Adj(X) in the slides means: all nodes adjacent to X in the current graph G
        for k in range(self.n - 1):
            for x in range(self.n):
                for y in range(self.n):
                    if not self.G[x, y]:
                        continue
                    # Try all subsets S of Adj(x) \ {y} with |S|=k,
                    # until an independence is found.
                    # Hint: use itertools.combinations

                    # Your code here (1 point)
                    adj_x = {z for z in range(self.n) if self.G[x, z] or self.G[z, x]}
                    for S in itertools.combinations(adj_x - {y}, k):
                        indep = self.independence_tester.test_independence(x, y, S)
                        if indep:
                            if self.verbose >= 1:
                                print("independence found: {0} and {1} given {{{2}}}"
                                      .format(self.node_names[x], self.node_names[y],
                                              ", ".join([self.node_names[v] for v in S])))
                            # Remove this edge.
                            self.G[x, y] = self.G[y, x] = False
                            # We use frozensets as keys in the dictionary self.sepset,
                            # because ordinary sets can't be used as keys to dictionaries.
                            self.sepset[frozenset([x, y])] = S
                            break
                        else:
                            if self.verbose >= 2:
                                print("dependence found: {0} and {1} given {{{2}}}"
                                      .format(self.node_names[x], self.node_names[y],
                                              ", ".join([self.node_names[v] for v in S])))

            # Do we need to continue with larger k?
            max_S_size = np.sum(self.G, axis=0) - 1
            if np.all(max_S_size < k + 1):
                break
        return

    def orient_v_structures(self):
        # PHASE III: Orient v-structures
        # Something to watch out for:
        # If the data are not faithful to any graph, the algorithm may end up trying
        # to orient a single edge in two different ways. You can choose either
        # orientation if this happens. But make sure not to accidentally delete such an edge!

        for x, y in itertools.combinations(range(self.n), 2):
            if self.G[x, y] or self.G[y, x]:
                continue
            for z in range(self.n):
                if z == x or z == y:
                    continue
                if (self.G[x, z] or self.G[z, x]) and (self.G[y, z] or self.G[z, y]):
                    if z not in self.sepset[frozenset([x, y])]:
                        self.G[x, z] = True
                        self.G[z, x] = False
                        self.G[y, z] = True
                        self.G[z, y] = False
        return

    def orientation_rules(self):
        # PHASE IV: Orientation rules

        # Your code here (2 points)
        changed = True
        while changed:
            changed = False

            # Rule 1
            for x, y in itertools.combinations(range(self.n), 2):
                if self.G[x, y] and self.G[y, x]:
                    for z in range(self.n):
                        if z == x or z == y:
                            continue
                        if (self.G[z, x] and not self.G[x, z]) and (not self.G[z, y] and not self.G[y, z]):
                            self.G[y, x] = False

            # Rule 2
            for x, y in itertools.combinations(range(self.n), 2):
                if self.G[x, y] and self.G[y, x]:
                    for z in range(self.n):
                        if z == x or z == y:
                            continue
                        if (not self.G[z, x] and self.G[x, z]) and (self.G[z, y] and not self.G[y, z]):
                            self.G[y, x] = False

            # Rule 3
            for x, y in itertools.combinations(range(self.n), 2):
                if self.G[x, y] and self.G[y, x]:
                    for z, w in itertools.combinations(range(self.n), 2):
                        if z == x or z == y or w == x or w == y:
                            continue
                        if (
                                (self.G[x, z] and self.G[z, x]) and
                                (self.G[x, w] and self.G[w, x]) and
                                (self.G[z, y] and not self.G[y, z]) and
                                (self.G[w, y] and not self.G[y, w])
                        ):
                            self.G[y, x] = False

        return

    def run(self):
        # The initialization step has already been performed by the __init__ method.
        # Perform the other phases one by one. Each of the following functions
        # modifies self.G, which represents the graph.
        self.skeleton_search()
        self.orient_v_structures()
        self.orientation_rules()

        return self.G

# %% [markdown]
# ## Testing the PC implementation
#
# To verify that the algorithm is working correctly, we will feed it output from an *oracle* instead of conditional independence test results from a data set. The oracle knows what the true graph is, and mimics the conditional independence test results that we would get for data that is Markov and faithful to that graph. In this situation, the PC algorithm will recover the Markov equivalence class of the true graph.

# %%
class IndependenceOracle:
    def __init__(self, true_G, node_names, n_observed=None):
        self.G = true_G
        self.n = true_G.shape[0]
        self.n_observed = n_observed if n_observed is not None else self.n
        self.node_names = node_names

    def test_independence(self, x, y, S):
        S_mask = np.zeros(self.n, dtype=bool)
        np.put(S_mask, S, True)
        return is_d_separated(self.G, x, y, S_mask)

# %% [markdown]
# We will compare the output of PC to the oracle's true graph for the graph `G1` we saw before, and for several other graphs. (You can add more tests to help chase down any bugs.)

# %%
oracle = IndependenceOracle(G1, node_names)
A = PC_algorithm(oracle, verbose=2)
G = A.run()
print("PASS" if np.all(G == G1) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# dependence found: X and Y given {}
# independence found: X and Z given {}
# independence found: X and W given {}
# dependence found: Y and X given {}
# dependence found: Y and Z given {}
# dependence found: Y and W given {}
# dependence found: Z and Y given {}
# dependence found: Z and W given {}
# dependence found: W and Y given {}
# dependence found: W and Z given {}
# dependence found: Y and X given {Z}
# dependence found: Y and X given {W}
# dependence found: Y and Z given {X}
# dependence found: Y and Z given {W}
# dependence found: Y and W given {X}
# independence found: Y and W given {Z}
# dependence found: Z and Y given {W}
# dependence found: Z and W given {Y}
# PASS

# %%
G2 = np.zeros((4, 4), dtype=bool)
G2[0, 2] = G2[1, 2] = G2[2, 3] = True
graph_to_graphviz(G2, node_names)

# %%
oracle = IndependenceOracle(G2, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G2) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# independence found: X and Y given {}
# independence found: X and W given {Z}
# independence found: Y and W given {Z}
# PASS

# %%
G3 = np.zeros((4, 4), dtype=bool)
G3[0, 2] = G3[1, 2] = G3[1, 3] = G3[2, 3] = True
graph_to_graphviz(G3, node_names)

# %%
oracle = IndependenceOracle(G3, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G3) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# independence found: X and Y given {}
# independence found: W and X given {Y, Z}
# PASS

# %%
G4 = np.logical_not(np.eye(4, dtype=bool))
G4[0, 1] = G4[1, 0] = False
G4[3, 0] = G4[3, 1] = G4[3, 2] = False
graph_to_graphviz(G4, node_names)

# %%
oracle = IndependenceOracle(G4, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G4) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# independence found: X and Y given {Z}
# PASS

# %%
# Example of a case for which no DAG exists that is Markov and faithful to the distribution.
# L is a latent variable that the PC algorithm won't know about. PC's output should be either
# X --> Y --> Z <-- W or
# X --> Y <-- Z <-- W.
# If there is no edge between Y and Z in your output, this most likely indicates a bug in
# your implementation of phase III.
G5 = np.zeros((5, 5), dtype=bool)
G5[0, 1] = G5[4, 1] = True
G5[3, 2] = G5[4, 2] = True
graph_to_graphviz(G5, ['X', 'Y', 'Z', 'W', 'L'])

# %%
oracle = IndependenceOracle(G5, node_names, n_observed=4)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if G[0, 1] and G[3, 2] and (G[1, 2] or G[2, 1]) and np.sum(np.logical_or(G, G.T)) == 6 else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# independence found: X and Z given {}
# independence found: X and W given {}
# independence found: Y and W given {}
# PASS

# %% [markdown]
# ## Running PC on data
# In this second part of the assignment, you will apply the PC algorithm to the biological dataset of Sachs et al. (2005). In this dataset, the columns represent 11 different proteins, which were measured in thousands of human immune system cells. Each row is a single cell. The cells were prepared in different ways, by adding different chemicals some time before the measurements were made. A twelfth column, labeled `experiment`, indicates in which way that cell was prepared. We can think of `experiment=1` as denoting the observational data, and other values of `experiment` (2 through 14) as various interventional datasets.

# %%
import pandas as pd

all_data = pd.read_csv("sachs2005_combined.csv", sep='\t')
# Transform all columns except 'experiment' by taking the logarithm of 10 + the original value
all_data.loc[:, all_data.columns != 'experiment'] = np.log(10 + all_data.loc[:, all_data.columns != 'experiment'])

# %% [markdown]
# We will apply the PC algorithm to just the observational data.
#
# Make a new dataframe containing only the data where experiment equals 1. Remove the `experiment` column from this dataframe. Check the shape of your dataframe: it should be `(853, 11)`.

# %%
# Your code here (0.5 point)
filtered_data = all_data[all_data['experiment'] == 1].drop('experiment', axis=1)
filtered_data.shape
# Out:
# (853, 11)

# %% [markdown]
# To run the PC algorithm on data, we need to perform (conditional) independence tests. The code below implements a simple test (based on [partial correlation](https://en.wikipedia.org/wiki/Partial_correlation)). It assumes the data come from a linear structural causal model, which they actually don't. We will use it anyway, because the alternatives (such as `CMIknn` (Runge, 2018)) are orders of magnitude slower, while partial correlation usually already gives decent results.
#
# As a statistical test, a conditional independence test works by computing a p-value. If a conditional independence exists, this p-value will be approximately uniformly distributed on the interval between 0 and 1. If the variables being tested are conditionally dependent, the p-value will be close to 0. PC wants to know a binary answer, so we will pick some threshold alpha and declare an independence if the p-value is larger than alpha.
#
# In statistical testing, alpha is often taken to be 0.05 or smaller. For PC, it may be more appropriate to pick a larger alpha instead. This is because as soon as PC finds a (conditional) independence between two variables, it will delete the edge between them and do no more tests between those two variables. If this happens while it shouldn't have, PC can't put the edge back. But in the reverse situation, if PC leaves an edge in place while it should have deleted it, there is still a possibility that the edge will be deleted later, when another test between those two variables reports a more convincing independence.

# %%
import math
from scipy.stats import beta


class IndependenceTester:
    def __init__(self, data, alpha, verbose=2, n_observed=None):
        # data: a pandas dataframe
        # alpha: the significance level to which the p-values are compared

        self.covariance_matrix = np.cov(data, rowvar=False, bias=True)
        self.num_samples = data.shape[0]
        self.n = data.shape[1]
        self.n_observed = n_observed if n_observed is not None else self.n
        self.verbose = verbose
        self.node_names = data.columns
        self.alpha = alpha

    def test_independence(self, x, y, S):
        # Compute the partial correlation of x and y given S by inverting a submatrix of the covariance matrix.
        xyS = [x, y]
        xyS.extend(S)
        precision_matrix = np.linalg.inv(self.covariance_matrix[np.ix_(xyS, xyS)])
        corr = -precision_matrix[0, 1] / math.sqrt(precision_matrix[0, 0] * precision_matrix[1, 1])
        # Compute the p-value as in the scipy manual for scipy.stats.pearsonr.
        dist = beta(self.num_samples / 2 - 1, self.num_samples / 2 - 1, loc=-1, scale=2)
        pval = 2 * dist.cdf(-abs(corr))
        test_result = pval > self.alpha
        if self.verbose >= 2 or (self.verbose >= 1 and test_result):
            print("test: {0} and {1} given {2} -> pval={{{3}}}".format(self.node_names[x], self.node_names[y],
                                                                       ", ".join([self.node_names[v] for v in S]),
                                                                       pval))
        return test_result

# %% [markdown]
# Using an IndependenceTester object (which works similarly to the IndependenceOracle we used earlier), run the PC algorithm on the observational data. Display the graph that comes out. You may experiment with different values of alpha; the graph you get should either be connected (i.e. consist of one [connected component](https://en.wikipedia.org/wiki/Component_%28graph_theory%29)), or have just two connected components.

# %%
# Your code here (1 point)
alpha = 0.3
def graph_from_dataframe(df):
    tester = IndependenceTester(df, alpha)
    A = PC_algorithm(tester)
    G = A.run()
    return graph_to_graphviz(G, tester.node_names)
graph_from_dataframe(filtered_data)
# Out:
# test: praf and pmek given  -> pval={6.283143797793529e-129}
# test: praf and plcg given  -> pval={0.5373868874563738}
# independence found: praf and plcg given {}
# test: praf and PIP2 given  -> pval={0.9727919297048786}
# independence found: praf and PIP2 given {}
# test: praf and PIP3 given  -> pval={0.33465938978893645}
# independence found: praf and PIP3 given {}
# test: praf and perk given  -> pval={0.6217936401751434}
# independence found: praf and perk given {}
# test: praf and pakts473 given  -> pval={0.3213233858427666}
# independence found: praf and pakts473 given {}
# test: praf and PKA given  -> pval={0.9668029258427108}
# independence found: praf and PKA given {}
# test: praf and PKC given  -> pval={0.20877767649395856}
# test: praf and P38 given  -> pval={0.09366579153448504}
# test: praf and pjnk given  -> pval={0.581956365050984}
# independence found: praf and pjnk given {}
# test: pmek and praf given  -> pval={6.283143797793529e-129}
# test: pmek and plcg given  -> pval={0.8066845247629127}
# independence found: pmek and plcg given {}
# test: pmek and PIP2 given  -> pval={0.2629515450360323}
# test: pmek and PIP3 given  -> pval={0.04715985362346153}
# test: pmek and perk given  -> pval={0.5704656795447938}
# independence found: pmek and perk given {}
# test: pmek and pakts473 given  -> pval={0.6961447497712355}
# independence found: pmek and pakts473 given {}
# test: pmek and PKA given  -> pval={0.8780133772321392}
# independence found: pmek and PKA given {}
# test: pmek and PKC given  -> pval={0.24548793643262432}
# test: pmek and P38 given  -> pval={0.21089683676303625}
# test: pmek and pjnk given  -> pval={0.21503599041809268}
# test: plcg and PIP2 given  -> pval={0.01476011661712301}
# test: plcg and PIP3 given  -> pval={0.00010862440580757683}
# test: plcg and perk given  -> pval={0.2994093118376485}
# test: plcg and pakts473 given  -> pval={0.4360089287896872}
# independence found: plcg and pakts473 given {}
# test: plcg and PKA given  -> pval={0.6791534824965426}
# independence found: plcg and PKA given {}
# test: plcg and PKC given  -> pval={0.7514732463603286}
# independence found: plcg and PKC given {}
# test: plcg and P38 given  -> pval={0.9884312693084788}
# independence found: plcg and P38 given {}
# test: plcg and pjnk given  -> pval={0.0819108325584823}
# test: PIP2 and pmek given  -> pval={0.2629515450360323}
# test: PIP2 and plcg given  -> pval={0.01476011661712301}
# test: PIP2 and PIP3 given  -> pval={6.640724688681886e-31}
# test: PIP2 and perk given  -> pval={0.2567905663208528}
# test: PIP2 and pakts473 given  -> pval={0.6414570791003115}
# independence found: PIP2 and pakts473 given {}
# test: PIP2 and PKA given  -> pval={0.4541744146187497}
# independence found: PIP2 and PKA given {}
# test: PIP2 and PKC given  -> pval={0.5810493328129241}
# independence found: PIP2 and PKC given {}
# test: PIP2 and P38 given  -> pval={0.8394313692868021}
# independence found: PIP2 and P38 given {}
# test: PIP2 and pjnk given  -> pval={0.8359516510501519}
# independence found: PIP2 and pjnk given {}
# test: PIP3 and pmek given  -> pval={0.04715985362346153}
# test: PIP3 and plcg given  -> pval={0.00010862440580757683}
# test: PIP3 and PIP2 given  -> pval={6.640724688681883e-31}
# test: PIP3 and perk given  -> pval={0.26600053639646803}
# test: PIP3 and pakts473 given  -> pval={0.2419716995414256}
# test: PIP3 and PKA given  -> pval={0.9987535723897436}
# independence found: PIP3 and PKA given {}
# test: PIP3 and PKC given  -> pval={0.6744562666085026}
# independence found: PIP3 and PKC given {}
# test: PIP3 and P38 given  -> pval={0.9038552784559973}
# independence found: PIP3 and P38 given {}
# test: PIP3 and pjnk given  -> pval={0.47902156291732634}
# independence found: PIP3 and pjnk given {}
# test: perk and plcg given  -> pval={0.2994093118376485}
# test: perk and PIP2 given  -> pval={0.2567905663208528}
# test: perk and PIP3 given  -> pval={0.26600053639646803}
# test: perk and pakts473 given  -> pval={1.7027177448394547e-264}
# test: perk and PKA given  -> pval={7.112938819178983e-27}
# test: perk and PKC given  -> pval={0.6181218753841417}
# independence found: perk and PKC given {}
# test: perk and P38 given  -> pval={0.5038306351503561}
# independence found: perk and P38 given {}
# test: perk and pjnk given  -> pval={0.32196709252044703}
# independence found: perk and pjnk given {}
# test: pakts473 and PIP3 given  -> pval={0.2419716995414256}
# test: pakts473 and perk given  -> pval={1.702717744838865e-264}
# test: pakts473 and PKA given  -> pval={1.7181586613457438e-38}
# test: pakts473 and PKC given  -> pval={0.4382659417249419}
# independence found: pakts473 and PKC given {}
# test: pakts473 and P38 given  -> pval={0.9757079496959487}
# independence found: pakts473 and P38 given {}
# test: pakts473 and pjnk given  -> pval={0.5651487944613075}
# independence found: pakts473 and pjnk given {}
# test: PKA and perk given  -> pval={7.112938819178983e-27}
# test: PKA and pakts473 given  -> pval={1.7181586613456018e-38}
# test: PKA and PKC given  -> pval={0.2720205079127216}
# test: PKA and P38 given  -> pval={0.4308722466820051}
# independence found: PKA and P38 given {}
# test: PKA and pjnk given  -> pval={0.33883752654591714}
# independence found: PKA and pjnk given {}
# test: PKC and praf given  -> pval={0.20877767649395856}
# test: PKC and pmek given  -> pval={0.24548793643262432}
# test: PKC and PKA given  -> pval={0.2720205079127216}
# test: PKC and P38 given  -> pval={8.847651325237508e-116}
# test: PKC and pjnk given  -> pval={2.1669122412803614e-15}
# test: P38 and praf given  -> pval={0.09366579153448504}
# test: P38 and pmek given  -> pval={0.21089683676303625}
# test: P38 and PKC given  -> pval={8.847651325237508e-116}
# test: P38 and pjnk given  -> pval={0.014289554530539908}
# test: pjnk and pmek given  -> pval={0.21503599041809268}
# test: pjnk and plcg given  -> pval={0.0819108325584823}
# test: pjnk and PKC given  -> pval={2.1669122412806253e-15}
# test: pjnk and P38 given  -> pval={0.014289554530539908}
# test: praf and pmek given PKC -> pval={1.144690016303927e-128}
# test: praf and pmek given P38 -> pval={1.3693972874497091e-128}
# test: praf and PKC given pmek -> pval={0.5363683941336136}
# independence found: praf and PKC given {pmek}
# test: praf and P38 given pmek -> pval={0.26263614236099875}
# test: pmek and praf given PIP2 -> pval={3.564927810534294e-129}
# test: pmek and praf given PIP3 -> pval={8.307585056561555e-129}
# test: pmek and praf given PKC -> pval={1.144690016303927e-128}
# test: pmek and praf given P38 -> pval={1.369397287450039e-128}
# test: pmek and praf given pjnk -> pval={9.65577367057649e-130}
# test: pmek and PIP2 given praf -> pval={0.12253638853096134}
# test: pmek and PIP2 given PIP3 -> pval={0.693799028746994}
# independence found: pmek and PIP2 given {PIP3}
# test: pmek and PIP3 given praf -> pval={0.06590927010730774}
# test: pmek and PIP3 given PKC -> pval={0.04513006339548169}
# test: pmek and PIP3 given pjnk -> pval={0.04364688276087195}
# test: pmek and PIP3 given P38 -> pval={0.04638061306507946}
# test: pmek and PKC given praf -> pval={0.6973621843634802}
# independence found: pmek and PKC given {praf}
# test: pmek and P38 given praf -> pval={0.9209342384454279}
# independence found: pmek and P38 given {praf}
# test: pmek and pjnk given praf -> pval={0.021616668131949533}
# test: pmek and pjnk given PIP3 -> pval={0.19656856547381094}
# test: plcg and PIP2 given pjnk -> pval={0.015090397483971696}
# test: plcg and PIP2 given PIP3 -> pval={0.2923059622834601}
# test: plcg and PIP2 given perk -> pval={0.016349224533069504}
# test: plcg and PIP3 given pjnk -> pval={0.00012518189902788226}
# test: plcg and PIP3 given PIP2 -> pval={0.0014472077024296536}
# test: plcg and PIP3 given perk -> pval={9.005685797145218e-05}
# test: plcg and perk given pjnk -> pval={0.27161013960644365}
# test: plcg and perk given PIP2 -> pval={0.3436233683878554}
# independence found: plcg and perk given {PIP2}
# test: plcg and pjnk given PIP2 -> pval={0.08390551972161109}
# test: plcg and pjnk given PIP3 -> pval={0.09670940269841616}
# test: PIP2 and plcg given PIP3 -> pval={0.2923059622834601}
# test: PIP2 and plcg given perk -> pval={0.016349224533069504}
# test: PIP2 and PIP3 given plcg -> pval={7.589662078689762e-30}
# test: PIP2 and PIP3 given perk -> pval={3.0244306641169853e-31}
# test: PIP2 and perk given plcg -> pval={0.29294862377823994}
# test: PIP2 and perk given PIP3 -> pval={0.0915162767623947}
# test: PIP3 and pmek given plcg -> pval={0.04886164068872782}
# test: PIP3 and pmek given PIP2 -> pval={0.09185679620156009}
# test: PIP3 and pmek given perk -> pval={0.04459949130036214}
# test: PIP3 and pmek given pakts473 -> pval={0.048733901737005196}
# test: PIP3 and plcg given pmek -> pval={0.0001121089780494193}
# test: PIP3 and plcg given PIP2 -> pval={0.0014472077024296536}
# test: PIP3 and plcg given perk -> pval={9.005685797145117e-05}
# test: PIP3 and plcg given pakts473 -> pval={9.356421578091636e-05}
# test: PIP3 and PIP2 given pmek -> pval={1.1546355197916914e-30}
# test: PIP3 and PIP2 given plcg -> pval={7.589662078689762e-30}
# test: PIP3 and PIP2 given perk -> pval={3.0244306641169853e-31}
# test: PIP3 and PIP2 given pakts473 -> pval={4.534037008642662e-31}
# test: PIP3 and perk given pmek -> pval={0.24857408139629325}
# test: PIP3 and perk given plcg -> pval={0.20715587964652118}
# test: PIP3 and perk given PIP2 -> pval={0.09433628672953527}
# test: PIP3 and perk given pakts473 -> pval={0.8490192798106005}
# independence found: PIP3 and perk given {pakts473}
# test: PIP3 and pakts473 given pmek -> pval={0.2516916432549213}
# test: PIP3 and pakts473 given plcg -> pval={0.1988455072600726}
# test: PIP3 and pakts473 given PIP2 -> pval={0.14475186974603996}
# test: perk and PIP2 given pakts473 -> pval={0.13843245078331415}
# test: perk and PIP2 given PKA -> pval={0.3531280928275214}
# independence found: perk and PIP2 given {PKA}
# test: perk and pakts473 given PKA -> pval={1.2976159505044589e-239}
# test: perk and PKA given pakts473 -> pval={0.39350901351928114}
# independence found: perk and PKA given {pakts473}
# test: pakts473 and PIP3 given perk -> pval={0.6818463507866394}
# independence found: pakts473 and PIP3 given {perk}
# test: pakts473 and perk given PKA -> pval={1.2976159505051323e-239}
# test: pakts473 and PKA given perk -> pval={2.1621497302845233e-13}
# test: PKA and pakts473 given PKC -> pval={2.19141508065579e-38}
# test: PKA and PKC given pakts473 -> pval={0.3952286089140116}
# independence found: PKA and PKC given {pakts473}
# test: PKC and P38 given pjnk -> pval={5.537775346627349e-118}
# test: PKC and pjnk given P38 -> pval={1.2737691906377506e-17}
# test: P38 and praf given PKC -> pval={0.26211769632187704}
# test: P38 and praf given pjnk -> pval={0.10180630492874679}
# test: P38 and PKC given praf -> pval={1.925975943764046e-115}
# test: P38 and PKC given pjnk -> pval={5.5377753466285935e-118}
# test: P38 and pjnk given praf -> pval={0.015411420961360356}
# test: P38 and pjnk given PKC -> pval={5.914697486906638e-05}
# test: pjnk and pmek given PKC -> pval={0.10737070064900912}
# test: pjnk and pmek given P38 -> pval={0.1767401254514983}
# test: pjnk and pmek given plcg -> pval={0.2088547004410304}
# test: pjnk and plcg given PKC -> pval={0.08589024264222171}
# test: pjnk and plcg given pmek -> pval={0.07981193616722003}
# test: pjnk and plcg given P38 -> pval={0.08104718040748472}
# test: pjnk and PKC given pmek -> pval={1.2681656504114214e-15}
# test: pjnk and PKC given plcg -> pval={2.253089555443749e-15}
# test: pjnk and PKC given P38 -> pval={1.273769190637656e-17}
# test: pjnk and P38 given PKC -> pval={5.914697486906638e-05}
# test: pjnk and P38 given pmek -> pval={0.012144538942762217}
# test: pjnk and P38 given plcg -> pval={0.014150923054615894}
# test: pmek and praf given pjnk, PIP3 -> pval={1.2160947432475788e-129}
# test: pmek and PIP3 given praf, pjnk -> pval={0.05744572565747953}
# test: pmek and pjnk given praf, PIP3 -> pval={0.018973629536725975}
# test: plcg and PIP2 given pjnk, PIP3 -> pval={0.2897516389337553}
# test: plcg and PIP3 given pjnk, PIP2 -> pval={0.0016279552416612149}
# test: plcg and pjnk given PIP2, PIP3 -> pval={0.09599859715350302}
# test: PIP3 and pmek given plcg, PIP2 -> pval={0.09312865247242134}
# test: PIP3 and plcg given pmek, PIP2 -> pval={0.0014646511659231227}
# test: PIP3 and PIP2 given pmek, plcg -> pval={1.295129731921199e-29}
# test: P38 and praf given PKC, pjnk -> pval={0.24480359335130852}
# test: P38 and PKC given praf, pjnk -> pval={1.0751241312708457e-117}
# test: P38 and pjnk given praf, PKC -> pval={5.624843150902036e-05}
# test: pjnk and pmek given PKC, P38 -> pval={0.12396842131370796}
# test: pjnk and pmek given PKC, plcg -> pval={0.10380110372878561}
# test: pjnk and pmek given P38, plcg -> pval={0.17131753023268606}
# test: pjnk and plcg given PKC, pmek -> pval={0.0830894946629832}
# test: pjnk and plcg given PKC, P38 -> pval={0.0898503572204974}
# test: pjnk and plcg given pmek, P38 -> pval={0.07875890856151473}
# test: pjnk and PKC given pmek, plcg -> pval={1.3109166560626266e-15}
# test: pjnk and PKC given pmek, P38 -> pval={9.680841558437065e-18}
# test: pjnk and PKC given plcg, P38 -> pval={1.3860476631369092e-17}
# test: pjnk and P38 given PKC, pmek -> pval={6.664753415422092e-05}
# test: pjnk and P38 given PKC, plcg -> pval={6.146202755762132e-05}
# test: pjnk and P38 given pmek, plcg -> pval={0.011997449401852257}
# test: pjnk and pmek given PKC, P38, plcg -> pval={0.11997325987611043}
# test: pjnk and plcg given PKC, pmek, P38 -> pval={0.08704076393020231}
# test: pjnk and PKC given pmek, plcg, P38 -> pval={1.0509225933098279e-17}
# test: pjnk and P38 given PKC, pmek, plcg -> pval={6.934704865890064e-05}

# %% [markdown]
# Now let's look at what else is in the dataset: the interventional data corresponding to different experiments. The PC algorithm did not look at this part of the dataset, but these additional experiments can obviously provide valuable information about the causal graph. In the following questions, we will investigate two examples of this. We will use the output of the PC algorithm that you obtained above to give us a rough idea of what the causal graph might look like. **So don't rerun the algorithm when answering the questions below!**
#
# The interventions in these experiment are not perfect interventions: they change the structural equation of a variable, but not by setting it to a constant. The new structural equation in the intervened model may still include all variables that were there in the original model. So in the graph of the intervened model, all arrows will still be there.
#
# Further, some of the interventions change not one, but multiple structural equations.
#
# For some of the interventions in the data, here is what they do according to many (but not all) experts:
# * experiment 5 adds the substance psitectorigenin, which modifies the amount of PIP2;
# * experiment 6 adds the substance U0126, which increases the *activity* of pmek. This means that the amount of pmek is not changed by the intervention, but for all *children* of pmek in the causal model, the structural equation changes to reflect that pmek now has a stronger effect on them. pmek is believed to have only one child in the true causal model, namely perk.
#
# (Source: Mooij et al., 2019, specifically Tables 2 & 3 and Figure 35(a))

# %% [markdown]
# Create two new dataframes, one containing all data from experiments 1 and 5, and one with the data from experiments 1 and 6. These dataframes should still have an 'experiment' column, so that you can tell for each row whether it came from the observational or the interventional dataset.

# %%
# Your code here (0.5 point)
df_1 = all_data[all_data['experiment'].isin((1, 5))]
df_2 = all_data[all_data['experiment'].isin((1, 6))]

# %% [markdown]
# **Question (1.5 points)**: In the dataframe for experiments 1 and 5, look at PIP2 and a variable adjacent to it in the output of PC (if there is more than one, pick one). Using about 200 words, answer the following questions: Based on looking at one or more plots (like scatterplots or histograms), which do you find more likely: that psitectorigenin directly modifies PIP2, or the neighbouring variable, or both? And what does the data for the two experiments seem to say about the direction of the arrow between PIP2 and its neighbour?
#
# Insert one or more markdown and code boxes below here to give your answer and the plots you base your answer on. (Please put your answer in markdown boxes, not as comments in your code!)

# %%
graph_from_dataframe(df_1.drop('experiment', axis=1))
# Out:
# test: praf and pmek given  -> pval={7.630796243031424e-205}
# test: praf and plcg given  -> pval={0.9276421187348255}
# independence found: praf and plcg given {}
# test: praf and PIP2 given  -> pval={0.8450304604195977}
# independence found: praf and PIP2 given {}
# test: praf and PIP3 given  -> pval={0.5247383720650672}
# independence found: praf and PIP3 given {}
# test: praf and perk given  -> pval={0.21311803759281767}
# test: praf and pakts473 given  -> pval={0.03557093232213936}
# test: praf and PKA given  -> pval={0.21979370386214334}
# test: praf and PKC given  -> pval={0.7868597982909679}
# independence found: praf and PKC given {}
# test: praf and P38 given  -> pval={0.8946837653147389}
# independence found: praf and P38 given {}
# test: praf and pjnk given  -> pval={0.615957477597374}
# independence found: praf and pjnk given {}
# test: pmek and praf given  -> pval={7.630796243033906e-205}
# test: pmek and plcg given  -> pval={0.5079077541101998}
# independence found: pmek and plcg given {}
# test: pmek and PIP2 given  -> pval={0.19650687531867572}
# test: pmek and PIP3 given  -> pval={0.209336509200737}
# test: pmek and perk given  -> pval={0.3481736063002379}
# independence found: pmek and perk given {}
# test: pmek and pakts473 given  -> pval={0.9171439030182515}
# independence found: pmek and pakts473 given {}
# test: pmek and PKA given  -> pval={0.5303099725870396}
# independence found: pmek and PKA given {}
# test: pmek and PKC given  -> pval={0.37973666642817294}
# independence found: pmek and PKC given {}
# test: pmek and P38 given  -> pval={0.09344122621204573}
# test: pmek and pjnk given  -> pval={0.1295322903968327}
# test: plcg and PIP2 given  -> pval={1.0585337500589202e-125}
# test: plcg and PIP3 given  -> pval={2.03484272402999e-50}
# test: plcg and perk given  -> pval={7.060848285610826e-08}
# test: plcg and pakts473 given  -> pval={8.422189864413523e-15}
# test: plcg and PKA given  -> pval={0.006198991682431901}
# test: plcg and PKC given  -> pval={8.42623043137643e-05}
# test: plcg and P38 given  -> pval={6.292471499466377e-07}
# test: plcg and pjnk given  -> pval={0.03353174062020273}
# test: PIP2 and pmek given  -> pval={0.19650687531867572}
# test: PIP2 and plcg given  -> pval={1.0585337500588353e-125}
# test: PIP2 and PIP3 given  -> pval={1.9867078112054356e-113}
# test: PIP2 and perk given  -> pval={3.224802769386251e-09}
# test: PIP2 and pakts473 given  -> pval={1.4299499157012855e-19}
# test: PIP2 and PKA given  -> pval={0.13638065683827721}
# test: PIP2 and PKC given  -> pval={2.2824910416418646e-07}
# test: PIP2 and P38 given  -> pval={1.4371714508948415e-09}
# test: PIP2 and pjnk given  -> pval={0.1353458444562575}
# test: PIP3 and pmek given  -> pval={0.209336509200737}
# test: PIP3 and plcg given  -> pval={2.03484272402999e-50}
# test: PIP3 and PIP2 given  -> pval={1.9867078112045928e-113}
# test: PIP3 and perk given  -> pval={2.4133172087385013e-06}
# test: PIP3 and pakts473 given  -> pval={1.8662921319766006e-08}
# test: PIP3 and PKA given  -> pval={0.6347066208753666}
# independence found: PIP3 and PKA given {}
# test: PIP3 and PKC given  -> pval={0.013088342568819786}
# test: PIP3 and P38 given  -> pval={0.00029831053980711967}
# test: PIP3 and pjnk given  -> pval={0.1496186571785518}
# test: perk and praf given  -> pval={0.21311803759281767}
# test: perk and plcg given  -> pval={7.060848285610728e-08}
# test: perk and PIP2 given  -> pval={3.224802769386251e-09}
# test: perk and PIP3 given  -> pval={2.4133172087385013e-06}
# test: perk and pakts473 given  -> pval={0.0}
# test: perk and PKA given  -> pval={2.352903574592778e-56}
# test: perk and PKC given  -> pval={0.18227134770138342}
# test: perk and P38 given  -> pval={0.23240593772697676}
# test: perk and pjnk given  -> pval={0.3583936785500517}
# independence found: perk and pjnk given {}
# test: pakts473 and praf given  -> pval={0.03557093232213936}
# test: pakts473 and plcg given  -> pval={8.422189864413523e-15}
# test: pakts473 and PIP2 given  -> pval={1.4299499157012855e-19}
# test: pakts473 and PIP3 given  -> pval={1.8662921319766006e-08}
# test: pakts473 and perk given  -> pval={0.0}
# test: pakts473 and PKA given  -> pval={2.8385997867285636e-86}
# test: pakts473 and PKC given  -> pval={0.03488303524194427}
# test: pakts473 and P38 given  -> pval={0.023992416909393088}
# test: pakts473 and pjnk given  -> pval={0.8145814672610631}
# independence found: pakts473 and pjnk given {}
# test: PKA and praf given  -> pval={0.21979370386214334}
# test: PKA and plcg given  -> pval={0.006198991682431901}
# test: PKA and PIP2 given  -> pval={0.13638065683827721}
# test: PKA and perk given  -> pval={2.352903574592778e-56}
# test: PKA and pakts473 given  -> pval={2.8385997867290466e-86}
# test: PKA and PKC given  -> pval={0.21080860116958092}
# test: PKA and P38 given  -> pval={0.5728029960899492}
# independence found: PKA and P38 given {}
# test: PKA and pjnk given  -> pval={0.5041510353084678}
# independence found: PKA and pjnk given {}
# test: PKC and plcg given  -> pval={8.42623043137643e-05}
# test: PKC and PIP2 given  -> pval={2.2824910416418646e-07}
# test: PKC and PIP3 given  -> pval={0.013088342568819786}
# test: PKC and perk given  -> pval={0.18227134770138342}
# test: PKC and pakts473 given  -> pval={0.03488303524194427}
# test: PKC and PKA given  -> pval={0.21080860116958092}
# test: PKC and P38 given  -> pval={1.3449391828912946e-265}
# test: PKC and pjnk given  -> pval={2.1867912341788465e-17}
# test: P38 and pmek given  -> pval={0.09344122621204573}
# test: P38 and plcg given  -> pval={6.292471499466377e-07}
# test: P38 and PIP2 given  -> pval={1.4371714508948415e-09}
# test: P38 and PIP3 given  -> pval={0.00029831053980711967}
# test: P38 and perk given  -> pval={0.23240593772697676}
# test: P38 and pakts473 given  -> pval={0.023992416909393088}
# test: P38 and PKC given  -> pval={1.3449391828909056e-265}
# test: P38 and pjnk given  -> pval={0.7247790289442598}
# independence found: P38 and pjnk given {}
# test: pjnk and pmek given  -> pval={0.1295322903968327}
# test: pjnk and plcg given  -> pval={0.03353174062020273}
# test: pjnk and PIP2 given  -> pval={0.1353458444562575}
# test: pjnk and PIP3 given  -> pval={0.1496186571785518}
# test: pjnk and PKC given  -> pval={2.1867912341788465e-17}
# test: praf and pmek given perk -> pval={7.907610274981285e-206}
# test: praf and pmek given pakts473 -> pval={1.8410606898413e-205}
# test: praf and pmek given PKA -> pval={9.041831451175841e-205}
# test: praf and perk given pmek -> pval={0.013679348933532067}
# test: praf and perk given pakts473 -> pval={0.2125142747463827}
# test: praf and perk given PKA -> pval={0.3964920088728782}
# independence found: praf and perk given {PKA}
# test: praf and pakts473 given pmek -> pval={0.007058020761971743}
# test: praf and pakts473 given PKA -> pval={0.08310339741926462}
# test: praf and PKA given pmek -> pval={0.2800698843729339}
# test: praf and PKA given pakts473 -> pval={0.7625319558275362}
# independence found: praf and PKA given {pakts473}
# test: pmek and praf given P38 -> pval={2.026132722982544e-205}
# test: pmek and praf given pjnk -> pval={1.2106707425759187e-205}
# test: pmek and praf given PIP2 -> pval={5.359265718796542e-205}
# test: pmek and praf given PIP3 -> pval={9.061646069386862e-205}
# test: pmek and PIP2 given praf -> pval={0.12336244282082191}
# test: pmek and PIP2 given P38 -> pval={0.2908555720027471}
# test: pmek and PIP2 given pjnk -> pval={0.21582829958677152}
# test: pmek and PIP2 given PIP3 -> pval={0.02357513665522456}
# test: pmek and PIP3 given praf -> pval={0.2668886496284899}
# test: pmek and PIP3 given P38 -> pval={0.15830771542686203}
# test: pmek and PIP3 given pjnk -> pval={0.1899503186179717}
# test: pmek and PIP3 given PIP2 -> pval={0.02486185975023682}
# test: pmek and P38 given praf -> pval={0.019420060766552488}
# test: pmek and P38 given pjnk -> pval={0.09578840451354369}
# test: pmek and P38 given PIP2 -> pval={0.1326190103775602}
# test: pmek and P38 given PIP3 -> pval={0.07237246810569455}
# test: pmek and pjnk given praf -> pval={0.01450098479158875}
# test: pmek and pjnk given P38 -> pval={0.1328967787597063}
# test: pmek and pjnk given PIP2 -> pval={0.14147442219354867}
# test: pmek and pjnk given PIP3 -> pval={0.11826907643512158}
# test: plcg and PIP2 given PIP3 -> pval={2.600959682459479e-81}
# test: plcg and PIP2 given perk -> pval={6.807099150940887e-121}
# test: plcg and PIP2 given pakts473 -> pval={2.8452849803558294e-115}
# test: plcg and PIP2 given PKA -> pval={3.214976575655034e-125}
# test: plcg and PIP2 given PKC -> pval={9.500937505295194e-123}
# test: plcg and PIP2 given P38 -> pval={3.1151509337210903e-121}
# test: plcg and PIP2 given pjnk -> pval={2.967699037836711e-125}
# test: plcg and PIP3 given PIP2 -> pval={1.3146858800276623e-05}
# test: plcg and PIP3 given perk -> pval={1.4670462951529143e-47}
# test: plcg and PIP3 given pakts473 -> pval={1.1748104324025154e-45}
# test: plcg and PIP3 given PKA -> pval={1.9797027714318268e-50}
# test: plcg and PIP3 given PKC -> pval={2.2546191139372363e-49}
# test: plcg and PIP3 given P38 -> pval={1.96777644409324e-48}
# test: plcg and PIP3 given pjnk -> pval={4.396826009527052e-50}
# test: plcg and perk given PIP2 -> pval={0.00840551047238565}
# test: plcg and perk given PIP3 -> pval={6.514553609768689e-05}
# test: plcg and perk given pakts473 -> pval={0.003375526708642512}
# test: plcg and perk given PKA -> pval={2.4798918507173866e-06}
# test: plcg and perk given PKC -> pval={1.2420357678766744e-07}
# test: plcg and perk given P38 -> pval={1.2620982454808822e-07}
# test: plcg and perk given pjnk -> pval={8.80400530124687e-08}
# test: plcg and pakts473 given PIP2 -> pval={0.0004545915814533206}
# test: plcg and pakts473 given PIP3 -> pval={5.736704241231603e-10}
# test: plcg and pakts473 given perk -> pval={2.8444833340290864e-10}
# test: plcg and pakts473 given PKA -> pval={2.547622364302143e-13}
# test: plcg and pakts473 given PKC -> pval={2.9874340423869e-14}
# test: plcg and pakts473 given P38 -> pval={4.424580429955922e-14}
# test: plcg and pakts473 given pjnk -> pval={8.535061804425327e-15}
# test: plcg and PKA given PIP2 -> pval={0.021651327653639925}
# test: plcg and PKA given PIP3 -> pval={0.006013580480540123}
# test: plcg and PKA given perk -> pval={0.4289868520993779}
# independence found: plcg and PKA given {perk}
# test: plcg and PKC given PIP2 -> pval={0.16975357465755037}
# test: plcg and PKC given PIP3 -> pval={0.0010880335807321349}
# test: plcg and PKC given perk -> pval={0.00015044065165500798}
# test: plcg and PKC given pakts473 -> pval={0.0003167199332033703}
# test: plcg and PKC given P38 -> pval={0.6113128736050435}
# independence found: plcg and PKC given {P38}
# test: plcg and P38 given PIP2 -> pval={0.038608121136887066}
# test: plcg and P38 given PIP3 -> pval={7.349993321663862e-05}
# test: plcg and P38 given perk -> pval={1.1281634560309212e-06}
# test: plcg and P38 given pakts473 -> pval={3.4352533405532575e-06}
# test: plcg and P38 given pjnk -> pval={6.679655504600091e-07}
# test: plcg and pjnk given PIP2 -> pval={0.11675903629255523}
# test: plcg and pjnk given PIP3 -> pval={0.08407320274842617}
# test: plcg and pjnk given perk -> pval={0.04311019247720919}
# test: plcg and pjnk given pakts473 -> pval={0.03404946209963344}
# test: plcg and pjnk given P38 -> pval={0.03586885013220098}
# test: PIP2 and pmek given plcg -> pval={0.2671472312815096}
# test: PIP2 and pmek given PIP3 -> pval={0.02357513665522456}
# test: PIP2 and pmek given perk -> pval={0.24260463129802215}
# test: PIP2 and pmek given pakts473 -> pval={0.17790020133597623}
# test: PIP2 and pmek given PKA -> pval={0.18832584526295265}
# test: PIP2 and pmek given PKC -> pval={0.23395054370054677}
# test: PIP2 and pmek given P38 -> pval={0.2908555720027471}
# test: PIP2 and pmek given pjnk -> pval={0.21582829958677152}
# test: PIP2 and plcg given pmek -> pval={1.3174216541339286e-125}
# test: PIP2 and plcg given PIP3 -> pval={2.600959682459679e-81}
# test: PIP2 and plcg given perk -> pval={6.807099150943562e-121}
# test: PIP2 and plcg given pakts473 -> pval={2.8452849803562482e-115}
# test: PIP2 and plcg given PKA -> pval={3.214976575655034e-125}
# test: PIP2 and plcg given PKC -> pval={9.500937505298021e-123}
# test: PIP2 and plcg given P38 -> pval={3.1151509337210903e-121}
# test: PIP2 and plcg given pjnk -> pval={2.9676990378358186e-125}
# test: PIP2 and PIP3 given pmek -> pval={3.514687103643124e-114}
# test: PIP2 and PIP3 given plcg -> pval={5.03684344508697e-69}
# test: PIP2 and PIP3 given perk -> pval={1.9754921634378025e-109}
# test: PIP2 and PIP3 given pakts473 -> pval={7.485215332974832e-107}
# test: PIP2 and PIP3 given PKA -> pval={2.0986881775063294e-113}
# test: PIP2 and PIP3 given PKC -> pval={4.250107465096973e-112}
# test: PIP2 and PIP3 given P38 -> pval={1.163677810799626e-110}
# test: PIP2 and PIP3 given pjnk -> pval={4.1321455048779225e-113}
# test: PIP2 and perk given pmek -> pval={3.767333378266193e-09}
# test: PIP2 and perk given plcg -> pval={0.0003216082800759988}
# test: PIP2 and perk given PIP3 -> pval={4.446880900839658e-05}
# test: PIP2 and perk given pakts473 -> pval={2.9190210916932865e-05}
# test: PIP2 and perk given PKA -> pval={7.390337175322445e-09}
# test: PIP2 and perk given PKC -> pval={6.6868628804361825e-09}
# test: PIP2 and perk given P38 -> pval={6.341905845741977e-09}
# test: PIP2 and perk given pjnk -> pval={3.837362920932523e-09}
# test: PIP2 and pakts473 given pmek -> pval={1.3275007253023616e-19}
# test: PIP2 and pakts473 given plcg -> pval={5.621873464010228e-09}
# test: PIP2 and pakts473 given PIP3 -> pval={6.535262833331132e-13}
# test: PIP2 and pakts473 given perk -> pval={1.0529525342822664e-15}
# test: PIP2 and pakts473 given PKA -> pval={4.820602561719812e-21}
# test: PIP2 and pakts473 given PKC -> pval={8.114147480605594e-19}
# test: PIP2 and pakts473 given P38 -> pval={1.1713945194779437e-18}
# test: PIP2 and pakts473 given pjnk -> pval={1.4635509864378413e-19}
# test: PIP2 and PKA given pmek -> pval={0.13098030679803302}
# test: PIP2 and PKA given plcg -> pval={0.9842579350034822}
# independence found: PIP2 and PKA given {plcg}
# test: PIP2 and PKC given pmek -> pval={2.59975479049993e-07}
# test: PIP2 and PKC given plcg -> pval={0.00027954553933409135}
# test: PIP2 and PKC given PIP3 -> pval={5.474383381623537e-06}
# test: PIP2 and PKC given perk -> pval={4.760644691241269e-07}
# test: PIP2 and PKC given pakts473 -> pval={1.3521185255004373e-06}
# test: PIP2 and PKC given P38 -> pval={0.23100829665956166}
# test: PIP2 and PKC given pjnk -> pval={6.543211865119189e-07}
# test: PIP2 and P38 given pmek -> pval={1.9081873941112018e-09}
# test: PIP2 and P38 given plcg -> pval={6.0873795952896656e-05}
# test: PIP2 and P38 given PIP3 -> pval={1.0161666555339617e-06}
# test: PIP2 and P38 given perk -> pval={2.824200843920118e-09}
# test: PIP2 and P38 given pakts473 -> pval={1.2152654057317884e-08}
# test: PIP2 and P38 given PKC -> pval={0.0007857377017560623}
# test: PIP2 and P38 given pjnk -> pval={1.5176674848467103e-09}
# test: PIP2 and pjnk given pmek -> pval={0.1478940368099322}
# test: PIP2 and pjnk given plcg -> pval={0.6783979042380303}
# independence found: PIP2 and pjnk given {plcg}
# test: PIP3 and pmek given plcg -> pval={0.11092401089664762}
# test: PIP3 and pmek given PIP2 -> pval={0.02486185975023682}
# test: PIP3 and pmek given perk -> pval={0.16969458525666734}
# test: PIP3 and pmek given pakts473 -> pval={0.21021358869128373}
# test: PIP3 and pmek given PKC -> pval={0.18965565591741262}
# test: PIP3 and pmek given P38 -> pval={0.15830771542686203}
# test: PIP3 and pmek given pjnk -> pval={0.1899503186179717}
# test: PIP3 and plcg given pmek -> pval={1.2532946495384117e-50}
# test: PIP3 and plcg given PIP2 -> pval={1.31468588002761e-05}
# test: PIP3 and plcg given perk -> pval={1.4670462951529143e-47}
# test: PIP3 and plcg given pakts473 -> pval={1.1748104324025154e-45}
# test: PIP3 and plcg given PKC -> pval={2.2546191139372363e-49}
# test: PIP3 and plcg given P38 -> pval={1.96777644409268e-48}
# test: PIP3 and plcg given pjnk -> pval={4.396826009527052e-50}
# test: PIP3 and PIP2 given pmek -> pval={3.514687103643124e-114}
# test: PIP3 and PIP2 given plcg -> pval={5.036843445085644e-69}
# test: PIP3 and PIP2 given perk -> pval={1.9754921634378025e-109}
# test: PIP3 and PIP2 given pakts473 -> pval={7.48521533297342e-107}
# test: PIP3 and PIP2 given PKC -> pval={4.250107465096401e-112}
# test: PIP3 and PIP2 given P38 -> pval={1.1636778107998134e-110}
# test: PIP3 and PIP2 given pjnk -> pval={4.1321455048779225e-113}
# test: PIP3 and perk given pmek -> pval={2.053990292895762e-06}
# test: PIP3 and perk given plcg -> pval={0.002510192737544103}
# test: PIP3 and perk given PIP2 -> pval={0.04940527110875489}
# test: PIP3 and perk given pakts473 -> pval={0.6584610018406859}
# independence found: PIP3 and perk given {pakts473}
# test: PIP3 and pakts473 given pmek -> pval={1.872119495341565e-08}
# test: PIP3 and pakts473 given plcg -> pval={0.001741438487832891}
# test: PIP3 and pakts473 given PIP2 -> pval={0.23572137694782855}
# test: PIP3 and pakts473 given PKC -> pval={3.555224409101898e-08}
# test: PIP3 and pakts473 given P38 -> pval={4.997257876963901e-08}
# test: PIP3 and pakts473 given pjnk -> pval={1.918549366491424e-08}
# test: PIP3 and PKC given pmek -> pval={0.012064188975531423}
# test: PIP3 and PKC given plcg -> pval={0.2420896439676854}
# test: PIP3 and PKC given PIP2 -> pval={0.8355717758938318}
# independence found: PIP3 and PKC given {PIP2}
# test: PIP3 and P38 given pmek -> pval={0.00023916416432980588}
# test: PIP3 and P38 given plcg -> pval={0.04607026559616168}
# test: PIP3 and P38 given PIP2 -> pval={0.5482369622170677}
# independence found: PIP3 and P38 given {PIP2}
# test: PIP3 and pjnk given pmek -> pval={0.13639832146104156}
# test: PIP3 and pjnk given plcg -> pval={0.4615806030118183}
# independence found: PIP3 and pjnk given {plcg}
# test: perk and plcg given PIP2 -> pval={0.00840551047238565}
# test: perk and plcg given pakts473 -> pval={0.003375526708642512}
# test: perk and plcg given PKA -> pval={2.4798918507174154e-06}
# test: perk and plcg given PKC -> pval={1.2420357678766744e-07}
# test: perk and plcg given P38 -> pval={1.2620982454808822e-07}
# test: perk and PIP2 given plcg -> pval={0.0003216082800759988}
# test: perk and PIP2 given pakts473 -> pval={2.9190210916932865e-05}
# test: perk and PIP2 given PKA -> pval={7.390337175322445e-09}
# test: perk and PIP2 given PKC -> pval={6.6868628804361825e-09}
# test: perk and PIP2 given P38 -> pval={6.341905845741977e-09}
# test: perk and pakts473 given plcg -> pval={0.0}
# test: perk and pakts473 given PIP2 -> pval={0.0}
# test: perk and pakts473 given PKA -> pval={0.0}
# test: perk and pakts473 given PKC -> pval={0.0}
# test: perk and pakts473 given P38 -> pval={0.0}
# test: perk and PKA given plcg -> pval={7.388128976776627e-55}
# test: perk and PKA given PIP2 -> pval={5.289923607399483e-56}
# test: perk and PKA given pakts473 -> pval={0.012362987226665963}
# test: perk and PKA given PKC -> pval={3.7096215047257514e-56}
# test: perk and PKA given P38 -> pval={2.738039077091275e-56}
# test: perk and PKC given plcg -> pval={0.40769187338399965}
# independence found: perk and PKC given {plcg}
# test: perk and P38 given plcg -> pval={0.5828906459593652}
# independence found: perk and P38 given {plcg}
# test: pakts473 and praf given plcg -> pval={0.03376765024967544}
# test: pakts473 and praf given PIP2 -> pval={0.027919187790852094}
# test: pakts473 and praf given PIP3 -> pval={0.041970221804918204}
# test: pakts473 and praf given perk -> pval={0.035485624822524174}
# test: pakts473 and praf given PKA -> pval={0.08310339741926462}
# test: pakts473 and praf given PKC -> pval={0.036561150652654764}
# test: pakts473 and praf given P38 -> pval={0.03593274105706094}
# test: pakts473 and plcg given praf -> pval={8.050375121447307e-15}
# test: pakts473 and plcg given PIP2 -> pval={0.00045459158145333184}
# test: pakts473 and plcg given PIP3 -> pval={5.736704241231847e-10}
# test: pakts473 and plcg given perk -> pval={2.8444833340290864e-10}
# test: pakts473 and plcg given PKA -> pval={2.547622364302143e-13}
# test: pakts473 and plcg given PKC -> pval={2.9874340423866644e-14}
# test: pakts473 and plcg given P38 -> pval={4.424580429955922e-14}
# test: pakts473 and PIP2 given praf -> pval={1.1588407012253834e-19}
# test: pakts473 and PIP2 given plcg -> pval={5.621873464010228e-09}
# test: pakts473 and PIP2 given PIP3 -> pval={6.535262833331132e-13}
# test: pakts473 and PIP2 given perk -> pval={1.052952534282266e-15}
# test: pakts473 and PIP2 given PKA -> pval={4.820602561719812e-21}
# test: pakts473 and PIP2 given PKC -> pval={8.114147480605594e-19}
# test: pakts473 and PIP2 given P38 -> pval={1.1713945194780826e-18}
# test: pakts473 and PIP3 given praf -> pval={2.157062909518674e-08}
# test: pakts473 and PIP3 given plcg -> pval={0.001741438487832891}
# test: pakts473 and PIP3 given PIP2 -> pval={0.23572137694782855}
# test: pakts473 and PIP3 given perk -> pval={0.001956317853589051}
# test: pakts473 and PIP3 given PKA -> pval={1.1972950799271707e-09}
# test: pakts473 and PIP3 given PKC -> pval={3.555224409101898e-08}
# test: pakts473 and PIP3 given P38 -> pval={4.997257876963901e-08}
# test: pakts473 and perk given praf -> pval={0.0}
# test: pakts473 and perk given plcg -> pval={0.0}
# test: pakts473 and perk given PIP2 -> pval={0.0}
# test: pakts473 and perk given PIP3 -> pval={0.0}
# test: pakts473 and perk given PKA -> pval={0.0}
# test: pakts473 and perk given PKC -> pval={0.0}
# test: pakts473 and perk given P38 -> pval={0.0}
# test: pakts473 and PKA given praf -> pval={5.7681260045186144e-86}
# test: pakts473 and PKA given plcg -> pval={8.18099204313421e-85}
# test: pakts473 and PKA given PIP2 -> pval={9.859809767558212e-88}
# test: pakts473 and PKA given PIP3 -> pval={1.9476676262960221e-87}
# test: pakts473 and PKA given perk -> pval={4.3411018477281806e-33}
# test: pakts473 and PKA given PKC -> pval={5.9013907021495395e-86}
# test: pakts473 and PKA given P38 -> pval={2.901774016788737e-86}
# test: pakts473 and PKC given praf -> pval={0.035853213033396995}
# test: pakts473 and PKC given plcg -> pval={0.16156125252302617}
# test: pakts473 and PKC given PIP2 -> pval={0.312344226907542}
# independence found: pakts473 and PKC given {PIP2}
# test: pakts473 and P38 given praf -> pval={0.024232460199492253}
# test: pakts473 and P38 given plcg -> pval={0.17596744555332453}
# test: pakts473 and P38 given PIP2 -> pval={0.3323427035946468}
# independence found: pakts473 and P38 given {PIP2}
# test: PKA and perk given PKC -> pval={3.709621504726847e-56}
# test: PKA and perk given pakts473 -> pval={0.012362987226665102}
# test: PKA and pakts473 given PKC -> pval={5.9013907021495395e-86}
# test: PKA and pakts473 given perk -> pval={4.3411018477281806e-33}
# test: PKA and PKC given perk -> pval={0.41694326811754284}
# independence found: PKA and PKC given {perk}
# test: PKC and PIP2 given P38 -> pval={0.23100829665956166}
# test: PKC and PIP2 given pjnk -> pval={6.543211865119189e-07}
# test: PKC and P38 given pjnk -> pval={3.8350155857481334e-281}
# test: PKC and P38 given PIP2 -> pval={4.3317823806519756e-260}
# test: PKC and pjnk given P38 -> pval={4.5797825071595514e-33}
# test: PKC and pjnk given PIP2 -> pval={6.126795081323602e-17}
# test: P38 and pmek given PKC -> pval={0.13214890726933048}
# test: P38 and pmek given plcg -> pval={0.10762087258580504}
# test: P38 and pmek given PIP2 -> pval={0.13261901037756185}
# test: P38 and plcg given PKC -> pval={0.0019261730069954788}
# test: P38 and plcg given pmek -> pval={7.072597840271281e-07}
# test: P38 and plcg given PIP2 -> pval={0.03860812113688784}
# test: P38 and PIP2 given PKC -> pval={0.0007857377017560623}
# test: P38 and PIP2 given pmek -> pval={1.9081873941112018e-09}
# test: P38 and PIP2 given plcg -> pval={6.0873795952896656e-05}
# test: P38 and PKC given pmek -> pval={1.7684062359963038e-265}
# test: P38 and PKC given plcg -> pval={2.7077470555094386e-262}
# test: P38 and PKC given PIP2 -> pval={4.3317823806519756e-260}
# test: pjnk and pmek given PKC -> pval={0.1724172067416833}
# test: pjnk and pmek given plcg -> pval={0.13791087937441218}
# test: pjnk and plcg given PKC -> pval={0.17644098663683733}
# test: pjnk and plcg given pmek -> pval={0.03549013310645264}
# test: pjnk and PKC given pmek -> pval={2.7279414050768224e-17}
# test: pjnk and PKC given plcg -> pval={8.555072201359173e-17}
# test: pmek and praf given P38, pjnk -> pval={3.2770747449247064e-206}
# test: pmek and praf given P38, PIP2 -> pval={1.7001566957488129e-205}
# test: pmek and praf given P38, PIP3 -> pval={2.2800399965772556e-205}
# test: pmek and praf given pjnk, PIP2 -> pval={9.037018600851938e-206}
# test: pmek and praf given pjnk, PIP3 -> pval={1.3929481208880678e-205}
# test: pmek and praf given PIP2, PIP3 -> pval={5.587284406732161e-205}
# test: pmek and PIP2 given praf, P38 -> pval={0.2259635871284928}
# test: pmek and PIP2 given praf, pjnk -> pval={0.1457557167838993}
# test: pmek and PIP2 given praf, PIP3 -> pval={0.013582024933395562}
# test: pmek and PIP2 given P38, pjnk -> pval={0.3154579251798911}
# independence found: pmek and PIP2 given {P38, pjnk}
# test: pmek and PIP3 given praf, P38 -> pval={0.18531861181574827}
# test: pmek and PIP3 given praf, pjnk -> pval={0.23049347690606523}
# test: pmek and PIP3 given P38, pjnk -> pval={0.14295512809337343}
# test: pmek and P38 given praf, pjnk -> pval={0.02030980559411767}
# test: pmek and P38 given praf, PIP3 -> pval={0.014427490292602776}
# test: pmek and P38 given pjnk, PIP3 -> pval={0.07354122674770684}
# test: pmek and pjnk given praf, P38 -> pval={0.015159083350020499}
# test: pmek and pjnk given praf, PIP3 -> pval={0.012911097669080175}
# test: pmek and pjnk given P38, PIP3 -> pval={0.12026421859464971}
# test: plcg and PIP2 given PIP3, perk -> pval={3.881104517337001e-79}
# test: plcg and PIP2 given PIP3, pakts473 -> pval={1.8277948250799907e-75}
# test: plcg and PIP2 given PIP3, P38 -> pval={8.972954881525124e-79}
# test: plcg and PIP2 given PIP3, pjnk -> pval={3.7945939018489226e-81}
# test: plcg and PIP2 given perk, pakts473 -> pval={1.4050197701649662e-113}
# test: plcg and PIP2 given perk, P38 -> pval={1.182307221249384e-116}
# test: plcg and PIP2 given perk, pjnk -> pval={1.6457799260966066e-120}
# test: plcg and PIP2 given pakts473, P38 -> pval={1.9062255961871392e-111}
# test: plcg and PIP2 given pakts473, pjnk -> pval={7.701494538337056e-115}
# test: plcg and PIP2 given P38, pjnk -> pval={8.306423681183066e-121}
# test: plcg and PIP3 given PIP2, perk -> pval={2.1999473437587945e-05}
# test: plcg and PIP3 given PIP2, pakts473 -> pval={1.9315518725928816e-05}
# test: plcg and PIP3 given PIP2, P38 -> pval={1.4708179566249394e-05}
# test: plcg and PIP3 given PIP2, pjnk -> pval={1.4825691273709738e-05}
# test: plcg and PIP3 given perk, pakts473 -> pval={1.092885815267717e-45}
# test: plcg and PIP3 given perk, P38 -> pval={1.014923857718124e-45}
# test: plcg and PIP3 given perk, pjnk -> pval={2.861870470131484e-47}
# test: plcg and PIP3 given pakts473, P38 -> pval={5.271924600432987e-44}
# test: plcg and PIP3 given pakts473, pjnk -> pval={2.443902236199399e-45}
# test: plcg and PIP3 given P38, pjnk -> pval={4.1104797365011254e-48}
# test: plcg and perk given PIP2, PIP3 -> pval={0.014602934233981133}
# test: plcg and perk given PIP2, pakts473 -> pval={0.3685663001810609}
# independence found: plcg and perk given {PIP2, pakts473}
# test: plcg and pakts473 given P38, pjnk -> pval={4.461824182176887e-14}
# test: plcg and pakts473 given P38, PIP2 -> pval={0.000535785853139432}
# test: plcg and pakts473 given P38, PIP3 -> pval={1.393856778696371e-09}
# test: plcg and pakts473 given pjnk, PIP2 -> pval={0.00044393175864118324}
# test: plcg and pakts473 given pjnk, PIP3 -> pval={5.591294072009639e-10}
# test: plcg and pakts473 given PIP2, PIP3 -> pval={0.0006739234396382656}
# test: plcg and P38 given pjnk, PIP2 -> pval={0.03894682990787837}
# test: plcg and P38 given pjnk, PIP3 -> pval={7.536763314363455e-05}
# test: plcg and P38 given pjnk, pakts473 -> pval={3.62930107296389e-06}
# test: plcg and P38 given PIP2, PIP3 -> pval={0.0438077580509486}
# test: plcg and P38 given PIP2, pakts473 -> pval={0.04627515313533486}
# test: plcg and P38 given PIP3, pakts473 -> pval={0.00018408418766785442}
# test: plcg and pjnk given P38, PIP2 -> pval={0.11786810620868278}
# test: plcg and pjnk given P38, PIP3 -> pval={0.08657757802707482}
# test: plcg and pjnk given P38, pakts473 -> pval={0.036217284557316015}
# test: plcg and pjnk given PIP2, PIP3 -> pval={0.13526474505205957}
# test: plcg and pjnk given PIP2, pakts473 -> pval={0.11351743177077105}
# test: plcg and pjnk given PIP3, pakts473 -> pval={0.08151408498212963}
# test: PIP2 and plcg given PIP3, perk -> pval={3.881104517337782e-79}
# test: PIP2 and plcg given PIP3, pakts473 -> pval={1.8277948250799907e-75}
# test: PIP2 and plcg given PIP3, PKC -> pval={2.0422091949686552e-79}
# test: PIP2 and plcg given PIP3, P38 -> pval={8.972954881525124e-79}
# test: PIP2 and plcg given perk, pakts473 -> pval={1.4050197701652348e-113}
# test: PIP2 and plcg given perk, PKC -> pval={3.7108225786760373e-118}
# test: PIP2 and plcg given perk, P38 -> pval={1.182307221249384e-116}
# test: PIP2 and plcg given pakts473, PKC -> pval={8.183688845853841e-113}
# test: PIP2 and plcg given pakts473, P38 -> pval={1.9062255961879366e-111}
# test: PIP2 and plcg given PKC, P38 -> pval={3.5058512925481926e-121}
# test: PIP2 and PIP3 given plcg, perk -> pval={1.1597865840730167e-67}
# test: PIP2 and PIP3 given plcg, pakts473 -> pval={4.9148226897821956e-67}
# test: PIP2 and PIP3 given plcg, PKC -> pval={9.389160668297886e-69}
# test: PIP2 and PIP3 given plcg, P38 -> pval={3.4443357563860733e-68}
# test: PIP2 and PIP3 given perk, pakts473 -> pval={1.3029309453265693e-107}
# test: PIP2 and PIP3 given perk, PKC -> pval={3.013573553154349e-108}
# test: PIP2 and PIP3 given perk, P38 -> pval={7.791852467046055e-107}
# test: PIP2 and PIP3 given pakts473, PKC -> pval={8.503232374046021e-106}
# test: PIP2 and PIP3 given pakts473, P38 -> pval={1.7118744555463233e-104}
# test: PIP2 and PIP3 given PKC, P38 -> pval={7.798300485909125e-111}
# test: PIP2 and perk given plcg, PIP3 -> pval={0.009710139046726905}
# test: PIP2 and perk given plcg, pakts473 -> pval={0.0018569327126342372}
# test: PIP2 and perk given plcg, PKC -> pval={0.0004032225149634507}
# test: PIP2 and perk given plcg, P38 -> pval={0.0003699906520871898}
# test: PIP2 and perk given PIP3, pakts473 -> pval={4.691609283902734e-06}
# test: PIP2 and perk given PIP3, PKC -> pval={6.585101565429281e-05}
# test: PIP2 and perk given PIP3, P38 -> pval={5.8695227174479464e-05}
# test: PIP2 and perk given pakts473, PKC -> pval={4.469890753528759e-05}
# test: PIP2 and perk given pakts473, P38 -> pval={6.537589727601181e-05}
# test: PIP2 and perk given PKC, P38 -> pval={7.019949032879175e-09}
# test: PIP2 and pakts473 given plcg, PIP3 -> pval={6.26163732250291e-07}
# test: PIP2 and pakts473 given plcg, perk -> pval={3.000803226176709e-08}
# test: PIP2 and pakts473 given plcg, PKC -> pval={1.0188554337345854e-08}
# test: PIP2 and pakts473 given plcg, P38 -> pval={1.0409540162311368e-08}
# test: PIP2 and pakts473 given PIP3, perk -> pval={7.366121243082749e-14}
# test: PIP2 and pakts473 given PIP3, PKC -> pval={1.9706246321288026e-12}
# test: PIP2 and pakts473 given PIP3, P38 -> pval={2.0851249564278937e-12}
# test: PIP2 and pakts473 given perk, PKC -> pval={4.407778933428633e-15}
# test: PIP2 and pakts473 given perk, P38 -> pval={9.680521316697854e-15}
# test: PIP2 and pakts473 given PKC, P38 -> pval={1.3519435611125687e-18}
# test: PIP2 and PKC given plcg, PIP3 -> pval={0.0005432071822540594}
# test: PIP2 and PKC given plcg, perk -> pval={0.00035039192868916206}
# test: PIP2 and PKC given plcg, pakts473 -> pval={0.0005189449193145123}
# test: PIP2 and PKC given plcg, P38 -> pval={0.27356894777861396}
# test: PIP2 and PKC given PIP3, perk -> pval={8.076137298672484e-06}
# test: PIP2 and PKC given PIP3, pakts473 -> pval={1.7012398400697217e-05}
# test: PIP2 and PKC given PIP3, P38 -> pval={0.13504165310632113}
# test: PIP2 and PKC given perk, pakts473 -> pval={2.059842014097043e-06}
# test: PIP2 and PKC given perk, P38 -> pval={0.26603872772881665}
# test: PIP2 and PKC given pakts473, P38 -> pval={0.2832340384294837}
# test: PIP2 and P38 given plcg, PIP3 -> pval={0.00046709218368405625}
# test: PIP2 and P38 given plcg, perk -> pval={6.991761077774705e-05}
# test: PIP2 and P38 given plcg, pakts473 -> pval={0.00011474243591840339}
# test: PIP2 and P38 given plcg, PKC -> pval={0.04361693546197727}
# test: PIP2 and P38 given PIP3, perk -> pval={1.3356924756041552e-06}
# test: PIP2 and P38 given PIP3, pakts473 -> pval={3.3231891746291732e-06}
# test: PIP2 and P38 given PIP3, PKC -> pval={0.019377630335480334}
# test: PIP2 and P38 given perk, pakts473 -> pval={2.671384693618965e-08}
# test: PIP2 and P38 given perk, PKC -> pval={0.0008268062069473111}
# test: PIP2 and P38 given pakts473, PKC -> pval={0.0013548890176716287}
# test: PIP3 and pmek given plcg, PIP2 -> pval={0.02431112935184756}
# test: PIP3 and pmek given plcg, pakts473 -> pval={0.11391709994599304}
# test: PIP3 and pmek given PIP2, pakts473 -> pval={0.0255480055460594}
# test: PIP3 and plcg given pmek, PIP2 -> pval={1.2882122946572002e-05}
# test: PIP3 and plcg given pmek, pakts473 -> pval={7.36599524390248e-46}
# test: PIP3 and plcg given PIP2, pakts473 -> pval={1.9315518725928318e-05}
# test: PIP3 and PIP2 given pmek, plcg -> pval={1.4149019288104545e-69}
# test: PIP3 and PIP2 given pmek, pakts473 -> pval={1.3514656700519526e-107}
# test: PIP3 and PIP2 given plcg, pakts473 -> pval={4.9148226897821956e-67}
# test: PIP3 and pakts473 given pmek, plcg -> pval={0.0017816607177330481}
# test: PIP3 and pakts473 given pmek, PIP2 -> pval={0.24373320803303816}
# test: PIP3 and pakts473 given plcg, PIP2 -> pval={0.41216744335878824}
# independence found: PIP3 and pakts473 given {plcg, PIP2}
# test: perk and PIP2 given pakts473, PKA -> pval={1.1637955679421696e-05}
# test: perk and pakts473 given PIP2, PKA -> pval={0.0}
# test: perk and PKA given PIP2, pakts473 -> pval={0.004652050279437804}
# test: pakts473 and praf given plcg, PIP2 -> pval={0.02877776251308356}
# test: pakts473 and praf given plcg, perk -> pval={0.032382169019041375}
# test: pakts473 and praf given plcg, PKA -> pval={0.07847629083913737}
# test: pakts473 and praf given PIP2, perk -> pval={0.026443154268714096}
# test: pakts473 and praf given PIP2, PKA -> pval={0.06631452616903705}
# test: pakts473 and praf given perk, PKA -> pval={0.051304637643315915}
# test: pakts473 and plcg given praf, PIP2 -> pval={0.0004674849844717393}
# test: pakts473 and plcg given praf, perk -> pval={2.6254660384567903e-10}
# test: pakts473 and plcg given praf, PKA -> pval={2.4297820969422994e-13}
# test: pakts473 and plcg given PIP2, perk -> pval={0.0130907770622618}
# test: pakts473 and plcg given PIP2, PKA -> pval={0.005770984556474081}
# test: pakts473 and plcg given perk, PKA -> pval={2.1770181008096786e-10}
# test: pakts473 and PIP2 given praf, plcg -> pval={4.882383920214724e-09}
# test: pakts473 and PIP2 given praf, perk -> pval={8.14829414735673e-16}
# test: pakts473 and PIP2 given praf, PKA -> pval={4.0006279989593505e-21}
# test: pakts473 and PIP2 given plcg, perk -> pval={3.000803226176709e-08}
# test: pakts473 and PIP2 given plcg, PKA -> pval={6.393877896213847e-11}
# test: pakts473 and PIP2 given perk, PKA -> pval={6.386986367115464e-18}
# test: pakts473 and perk given praf, plcg -> pval={0.0}
# test: pakts473 and perk given praf, PIP2 -> pval={0.0}
# test: pakts473 and perk given praf, PKA -> pval={0.0}
# test: pakts473 and perk given plcg, PIP2 -> pval={0.0}
# test: pakts473 and perk given plcg, PKA -> pval={0.0}
# test: pakts473 and perk given PIP2, PKA -> pval={0.0}
# test: pakts473 and PKA given praf, plcg -> pval={1.6589870797717177e-84}
# test: pakts473 and PKA given praf, PIP2 -> pval={2.050901051737705e-87}
# test: pakts473 and PKA given praf, perk -> pval={5.941443500267509e-33}
# test: pakts473 and PKA given plcg, PIP2 -> pval={1.0259999600884685e-86}
# test: pakts473 and PKA given plcg, perk -> pval={3.337236317807183e-33}
# test: pakts473 and PKA given PIP2, perk -> pval={2.733261073397827e-35}
# test: PKC and PIP2 given P38, pjnk -> pval={0.4160534905867776}
# independence found: PKC and PIP2 given {P38, pjnk}
# test: P38 and pmek given PKC, plcg -> pval={0.14266910601883556}
# test: P38 and pmek given PKC, PIP2 -> pval={0.1576289927243691}
# test: P38 and pmek given plcg, PIP2 -> pval={0.1316043363209268}
# test: P38 and plcg given PKC, pmek -> pval={0.0020542184069557616}
# test: P38 and plcg given PKC, PIP2 -> pval={0.12015508320326634}
# test: P38 and plcg given pmek, PIP2 -> pval={0.03833877437945654}
# test: P38 and PIP2 given PKC, pmek -> pval={0.000908972019696722}
# test: P38 and PIP2 given PKC, plcg -> pval={0.04361693546197727}
# test: P38 and PIP2 given pmek, plcg -> pval={7.190936674377605e-05}
# test: P38 and PKC given pmek, plcg -> pval={3.3745077874920674e-262}
# test: P38 and PKC given pmek, PIP2 -> pval={4.945461720800436e-260}
# test: P38 and PKC given plcg, PIP2 -> pval={1.1002922394009987e-259}
# test: pjnk and pmek given PKC, plcg -> pval={0.17827257231573676}
# test: pjnk and plcg given PKC, pmek -> pval={0.18245475703449698}
# test: pjnk and PKC given pmek, plcg -> pval={1.0421177339531767e-16}
# test: pmek and praf given P38, pjnk, PIP3 -> pval={3.537438983355221e-206}
# test: pmek and PIP3 given praf, P38, pjnk -> pval={0.15801497332359962}
# test: pmek and P38 given praf, pjnk, PIP3 -> pval={0.014797875567127984}
# test: pmek and pjnk given praf, P38, PIP3 -> pval={0.013241485036599667}
# test: plcg and PIP2 given P38, pjnk, PIP3 -> pval={1.2863777350778571e-78}
# test: plcg and PIP2 given P38, pjnk, pakts473 -> pval={4.9314969307204875e-111}
# test: plcg and PIP2 given P38, PIP3, pakts473 -> pval={3.057552646437352e-73}
# test: plcg and PIP2 given pjnk, PIP3, pakts473 -> pval={2.6731642142830784e-75}
# test: plcg and PIP3 given P38, pjnk, PIP2 -> pval={1.6567001092418923e-05}
# test: plcg and PIP3 given P38, pjnk, pakts473 -> pval={1.0646002027614671e-43}
# test: plcg and PIP3 given P38, PIP2, pakts473 -> pval={2.1379702493315343e-05}
# test: plcg and PIP3 given pjnk, PIP2, pakts473 -> pval={2.177424591587776e-05}
# test: plcg and pakts473 given P38, pjnk, PIP2 -> pval={0.0005232349437991212}
# test: plcg and pakts473 given P38, pjnk, PIP3 -> pval={1.357469577277411e-09}
# test: plcg and pakts473 given P38, PIP2, PIP3 -> pval={0.0007859769475335358}
# test: plcg and pakts473 given pjnk, PIP2, PIP3 -> pval={0.000657680130409812}
# test: plcg and P38 given pjnk, PIP2, PIP3 -> pval={0.044133291865260875}
# test: plcg and P38 given pjnk, PIP2, pakts473 -> pval={0.04668806978194248}
# test: plcg and P38 given pjnk, PIP3, pakts473 -> pval={0.00018864395980866357}
# test: plcg and P38 given PIP2, PIP3, pakts473 -> pval={0.05192468031133954}
# test: plcg and pjnk given P38, PIP2, PIP3 -> pval={0.1363640348368448}
# test: plcg and pjnk given P38, PIP2, pakts473 -> pval={0.11460078788733777}
# test: plcg and pjnk given P38, PIP3, pakts473 -> pval={0.08386031865370153}
# test: plcg and pjnk given PIP2, PIP3, pakts473 -> pval={0.13135756651594324}
# test: PIP2 and plcg given P38, PIP3, perk -> pval={1.0977167768419293e-76}
# test: PIP2 and plcg given P38, PIP3, pakts473 -> pval={3.057552646437163e-73}
# test: PIP2 and plcg given P38, perk, pakts473 -> pval={6.12446688852047e-110}
# test: PIP2 and plcg given PIP3, perk, pakts473 -> pval={7.901183248716775e-74}
# test: PIP2 and PIP3 given P38, plcg, perk -> pval={7.419659102501489e-67}
# test: PIP2 and PIP3 given P38, plcg, pakts473 -> pval={2.7963095512676785e-66}
# test: PIP2 and PIP3 given P38, perk, pakts473 -> pval={2.7483307442638096e-105}
# test: PIP2 and PIP3 given plcg, perk, pakts473 -> pval={7.442440649551278e-68}
# test: PIP2 and perk given P38, plcg, PIP3 -> pval={0.010440124337398174}
# test: PIP2 and perk given P38, plcg, pakts473 -> pval={0.0026783340095923504}
# test: PIP2 and perk given P38, PIP3, pakts473 -> pval={9.592949433290466e-06}
# test: PIP2 and perk given plcg, PIP3, pakts473 -> pval={0.00024517904863376514}
# test: PIP2 and pakts473 given P38, plcg, PIP3 -> pval={9.639393705622322e-07}
# test: PIP2 and pakts473 given P38, plcg, perk -> pval={6.874220674383871e-08}
# test: PIP2 and pakts473 given P38, PIP3, perk -> pval={3.602541869931029e-13}
# test: PIP2 and pakts473 given plcg, PIP3, perk -> pval={1.9027677609159602e-08}
# test: PIP2 and P38 given plcg, PIP3, perk -> pval={0.0005005657546301265}
# test: PIP2 and P38 given plcg, PIP3, pakts473 -> pval={0.0007298978890366869}
# test: PIP2 and P38 given plcg, perk, pakts473 -> pval={0.0001638534201663852}
# test: PIP2 and P38 given PIP3, perk, pakts473 -> pval={6.788745389525579e-06}
# test: pakts473 and praf given plcg, PIP2, perk -> pval={0.026786167808708437}
# test: pakts473 and praf given plcg, PIP2, PKA -> pval={0.06733623595656892}
# test: pakts473 and praf given plcg, perk, PKA -> pval={0.0469397897593553}
# test: pakts473 and praf given PIP2, perk, PKA -> pval={0.03833367772647848}
# test: pakts473 and plcg given praf, PIP2, perk -> pval={0.013256631810241526}
# test: pakts473 and plcg given praf, PIP2, PKA -> pval={0.005852132225699122}
# test: pakts473 and plcg given praf, perk, PKA -> pval={2.0169110680293443e-10}
# test: pakts473 and plcg given PIP2, perk, PKA -> pval={0.0309537144232652}
# test: pakts473 and PIP2 given praf, plcg, perk -> pval={2.5362706250253928e-08}
# test: pakts473 and PIP2 given praf, plcg, PKA -> pval={5.625064382283613e-11}
# test: pakts473 and PIP2 given praf, perk, PKA -> pval={4.9784719344004294e-18}
# test: pakts473 and PIP2 given plcg, perk, PKA -> pval={4.81209811547327e-10}
# test: pakts473 and perk given praf, plcg, PIP2 -> pval={0.0}
# test: pakts473 and perk given praf, plcg, PKA -> pval={0.0}
# test: pakts473 and perk given praf, PIP2, PKA -> pval={0.0}
# test: pakts473 and perk given plcg, PIP2, PKA -> pval={0.0}
# test: pakts473 and PKA given praf, plcg, PIP2 -> pval={2.105484368099362e-86}
# test: pakts473 and PKA given praf, plcg, perk -> pval={4.584171459494653e-33}
# test: pakts473 and PKA given praf, PIP2, perk -> pval={3.765467095084272e-35}
# test: pakts473 and PKA given plcg, PIP2, perk -> pval={5.818146737188954e-35}
# test: P38 and pmek given PKC, plcg, PIP2 -> pval={0.15661125786903185}
# test: P38 and plcg given PKC, pmek, PIP2 -> pval={0.11940425359471288}
# test: P38 and PIP2 given PKC, pmek, plcg -> pval={0.04745894335931525}
# test: P38 and PKC given pmek, plcg, PIP2 -> pval={1.2574787411085125e-259}
# test: plcg and PIP2 given P38, pjnk, PIP3, pakts473 -> pval={4.397817849562677e-73}
# test: plcg and PIP3 given P38, pjnk, PIP2, pakts473 -> pval={2.4074185393535224e-05}
# test: plcg and pakts473 given P38, pjnk, PIP2, PIP3 -> pval={0.0007670915179110216}
# test: plcg and P38 given pjnk, PIP2, PIP3, pakts473 -> pval={0.052320862663242276}
# test: plcg and pjnk given P38, PIP2, PIP3, pakts473 -> pval={0.13243967184753364}
# test: PIP2 and plcg given P38, PIP3, perk, pakts473 -> pval={9.488908767704928e-72}
# test: PIP2 and PIP3 given P38, plcg, perk, pakts473 -> pval={4.3107067977753716e-67}
# test: PIP2 and perk given P38, plcg, PIP3, pakts473 -> pval={0.00035759616733655516}
# test: PIP2 and pakts473 given P38, plcg, PIP3, perk -> pval={3.9328051904952775e-08}
# test: PIP2 and P38 given plcg, PIP3, perk, pakts473 -> pval={0.0010687342737079554}
# test: pakts473 and praf given plcg, PIP2, perk, PKA -> pval={0.03866595382015044}
# test: pakts473 and plcg given praf, PIP2, perk, PKA -> pval={0.031219408637789978}
# test: pakts473 and PIP2 given praf, plcg, perk, PKA -> pval={4.067966908130251e-10}
# test: pakts473 and perk given praf, plcg, PIP2, PKA -> pval={0.0}
# test: pakts473 and PKA given praf, plcg, PIP2, perk -> pval={7.984935023018384e-35}

# %%
from matplotlib.axes import Axes
import matplotlib.pyplot as plt
ax_1, ax_2 = df_1[df_1['experiment']==1]['PIP2'].plot(kind='hist'), df_1[df_1['experiment']==5]['PIP2'].plot(kind='hist')
ax_1: Axes

plt.legend()

# %% [markdown]
# **Question (1.5 points)**: In the dataframe for experiments 1 and 6, look at pmek, perk, and any other variables adjacent to pmek in the output of PC. Assume it is true that adding U0126 produces an intervention on the *activity* of pmek. What would you expect to see in the data if the graph found by PC was correct? Would you propose any changes to that graph based on the data?
#
# Again put your answer (about 200 words) with accompanying plots in new boxes below here.

# %% [markdown]
# ---
#
# You are almost done! Before handing in, make sure that the code you hand in works, and that all plots are shown. **Submit just one file per team.** Name the submitted file according to your and your collaborator's last name (`submitter_collaborator.ipynb`).

# %% [markdown]
# ### References
# * J. M. Mooij, S. Magliacane, and T. Claassen, "Joint Causal Inference from Multiple Contexts," [arXiv:1611.10351v4](https://arxiv.org/abs/1611.10351), 2019.
# * J. Runge, "Conditional Independence Testing Based on a Nearest-Neighbor Estimator of Conditional Mutual Information" In Proceedings of the 21st International Conference on Artificial Intelligence and Statistics, http://proceedings.mlr.press/v84/runge18a.html, 2018.
# * K. Sachs, O. Perez, D. Pe’er, D. A. Lauffenburger, and G. P. Nolan, "Causal protein-signaling networks derived from multiparameter single-cell data," Science, vol. 308, no. 5721, pp. 523–529, 2005.
